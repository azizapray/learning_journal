# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\acer\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\acer\anaconda3\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\acer\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)

# %%
# !pip install request
# Out:
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.1.0-py3-none-any.whl (958 kB)
# Collecting trio~=0.17
#   Downloading trio-0.19.0-py3-none-any.whl (356 kB)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\acer\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\acer\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\acer\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\acer\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: idna in c:\users\acer\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: sniffio in c:\users\acer\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\acer\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\acer\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\acer\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\acer\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\acer\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\acer\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.16.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.13.0 outcome-1.1.0 selenium-4.1.0 trio-0.19.0 trio-websocket-0.9.2 wsproto-1.0.0

# %%
import requests
page = requests.get("https://www.gramedia.com/categories/buku")
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome('chromedriver')

url="https://www.gramedia.com/categories/buku"
driver.get(url)
html = driver.page_source

soup = BeautifulSoup(html, "html.parser")
print(soup.prettify()[:700])
# Out:
# <html class="" lang="id">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#281e5a" name="theme-color"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/assets/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="manifest.json" rel="manifest"/>
#   <link href="/assets/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="z91Vp6ZYo9UoX5D4ur6i4Lrl0l1j3DDoCH08fD3n53g" name="google-site-verification"/>
#   <meta content="810657685650228" property="fb:app_id"/>
#   <style>
#    .async-hide {
#         opacity: 0 !important
#     }
#   </style>
#   <script async="" src="https://cdn.

# %%
soup.find_all('div',{"class":"list-title"})
# Out:
# [<div _ngcontent-web-gramedia-c26="" class="list-title">A+</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Lavender</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">30 Doa Salafush Shalih</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Ramuan Tradisional Anti Segala Virus</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Malaikat Di Sisi Kita</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Buku Bisakah Aku yang Pelupa Memiliki Ingatan Super?</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">The Art of Self Talk-ing</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Paket Pandai Baca Tulis Hitung Anak Umur Paud / Tk</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Kisah 25 Nabi Dan Khulafaur Rasyidin</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Indonesia Sebagai Poros Maritim Dunia</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Kitab Lulus Utbk Sbmptn Saintek 2022</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Pendidikan Untuk Apa dan Untuk Siapa?</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Petualangan Lu si Ulat Bulu : Topi Jerami Lu</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Petualangan Lu si Ulat Bulu : Apakah Lu diculik?</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Kenduri Arwah</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Intelijen dan Kekuasaan Soeharto</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Petualangan Lu si Ulat Bulu : Kenari Untuk Pipu</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">KOLONI Sinawang</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Plants VS Zombies - Komik Dinosaurus : Berburu Harta Karun di Periode Jura</div>]

# %%
for div_tag in soup.find_all('div',{"class":"list-title"}):
    print(div_tag.get_text())
# Out:
# A+
# Lavender
# Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4
# 30 Doa Salafush Shalih
# Ramuan Tradisional Anti Segala Virus
# Malaikat Di Sisi Kita
# Buku Bisakah Aku yang Pelupa Memiliki Ingatan Super?
# The Art of Self Talk-ing
# Paket Pandai Baca Tulis Hitung Anak Umur Paud / Tk
# Kisah 25 Nabi Dan Khulafaur Rasyidin
# Indonesia Sebagai Poros Maritim Dunia
# Kitab Lulus Utbk Sbmptn Saintek 2022
# Pendidikan Untuk Apa dan Untuk Siapa?
# Petualangan Lu si Ulat Bulu : Topi Jerami Lu
# Petualangan Lu si Ulat Bulu : Apakah Lu diculik?
# Kenduri Arwah
# Intelijen dan Kekuasaan Soeharto
# Petualangan Lu si Ulat Bulu : Kenari Untuk Pipu
# KOLONI Sinawang
# Plants VS Zombies - Komik Dinosaurus : Berburu Harta Karun di Periode Jura

# %%
import pandas as pd

data = pd.DataFrame()

data['Title'] = [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
data['Author'] = [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
data['Price'] = [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
data['Image'] = [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

links = []
for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
    try:
        links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
    except:
        pass

data['Link'] = links

data
# Out:
#                                                 Title  \
# 0                                                  A+
# 1                                            Lavender
# 2      Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4
# 3                              30 Doa Salafush Shalih
# 4                Ramuan Tradisional Anti Segala Virus
# 5                               Malaikat Di Sisi Kita
# 6   Buku Bisakah Aku yang Pelupa Memiliki Ingatan ...
# 7                            The Art of Self Talk-ing
# 8   Paket Pandai Baca Tulis Hitung Anak Umur Paud ...
# 9                Kisah 25 Nabi Dan Khulafaur Rasyidin
# 10              Indonesia Sebagai Poros Maritim Dunia
# 11               Kitab Lulus Utbk Sbmptn Saintek 2022
# 12              Pendidikan Untuk Apa dan Untuk Siapa?
# 13       Petualangan Lu si Ulat Bulu : Topi Jerami Lu
# 14   Petualangan Lu si Ulat Bulu : Apakah Lu diculik?
# 15                                      Kenduri Arwah
# 16                   Intelijen dan Kekuasaan Soeharto
# 17    Petualangan Lu si Ulat Bulu : Kenari Untuk Pipu
# 18                                    KOLONI Sinawang
# 19  Plants VS Zombies - Komik Dinosaurus : Berburu...
#
#                              Author       Price  \
# 0                     Ananda Putri    Rp 84.575
# 1              Astri Salvia Aznani    Rp 80.750
# 2    Prof. Dr. Muhammad az-Zuhaili   Rp 204.000
# 3                        OMAR None    Rp 58.650
# 4                   Argo Wikanjati    Rp 51.000
# 5                     Omar Suleman    Rp 58.650
# 6                   Cho Shin Young   Rp 100.000
# 7            Nisrina P. Utami None    Rp 56.000
# 8                         Kak Elly    Rp 67.150
# 9                Herdro Trilaksana    Rp 51.000
# 10       Poltak Partogi Nainggolan   Rp 136.000
# 11   Tim Guru dan Tentor Indonesia   Rp 169.150
# 12          Lucia Ratih Kusumadewi    Rp 42.500
# 13                      Norrattri     Rp 52.000
# 14                      Norrattri     Rp 52.000
# 15                       A.R Rizal    Rp 72.250
# 16        Diandra Megaputri Mengko    Rp 72.250
# 17                      Norrattri     Rp 52.000
# 18        Dedy Koerniawan Soesanto    Rp 36.000
# 19                   Xiao Jiangnan    Rp 84.000
#
#                                                 Image  \
# 0   https://cdn.gramedia.com/uploads/items/A__w149...
# 1   https://cdn.gramedia.com/uploads/items/Lavende...
# 2                  /assets/default-images/product.png
# 3   https://cdn.gramedia.com/uploads/items/30_Doa_...
# 4   https://cdn.gramedia.com/uploads/items/Ramuan_...
# 5   https://cdn.gramedia.com/uploads/items/Malaika...
# 6   https://cdn.gramedia.com/uploads/items/9786230...
# 7   https://cdn.gramedia.com/uploads/items/9786230...
# 8   https://cdn.gramedia.com/uploads/items/Paket_P...
# 9   https://cdn.gramedia.com/uploads/items/Kisah_2...
# 10  https://cdn.gramedia.com/uploads/items/Indones...
# 11  https://cdn.gramedia.com/uploads/items/Kitab_L...
# 12  https://cdn.gramedia.com/uploads/items/Pendidi...
# 13  https://cdn.gramedia.com/uploads/items/COVER_P...
# 14  https://cdn.gramedia.com/uploads/items/COVER_P...
# 15                 /assets/default-images/product.png
# 16                 /assets/default-images/product.png
# 17                 /assets/default-images/product.png
# 18                 /assets/default-images/product.png
# 19                 /assets/default-images/product.png
#
#                                                  Link
# 0               https://www.gramedia.com/products/a-3
# 1          https://www.gramedia.com/products/lavender
# 2   https://www.gramedia.com/products/fiqih-al-mut...
# 3   https://www.gramedia.com/products/30-doa-salaf...
# 4   https://www.gramedia.com/products/ramuan-tradi...
# 5   https://www.gramedia.com/products/malaikat-di-...
# 6   https://www.gramedia.com/products/buku-bisakah...
# 7   https://www.gramedia.com/products/the-art-of-s...
# 8   https://www.gramedia.com/products/paket-pandai...
# 9   https://www.gramedia.com/products/kisah-25-nab...
# 10  https://www.gramedia.com/products/indonesia-se...
# 11  https://www.gramedia.com/products/kitab-lulus-...
# 12  https://www.gramedia.com/products/pendidikan-u...
# 13  https://www.gramedia.com/products/petualangan-...
# 14  https://www.gramedia.com/products/petualangan-...
# 15    https://www.gramedia.com/products/kenduri-arwah
# 16  https://www.gramedia.com/products/intelijen-da...
# 17  https://www.gramedia.com/products/petualangan-...
# 18  https://www.gramedia.com/products/koloni-sinawang
# 19  https://www.gramedia.com/products/plants-vs-zo...

# %%
title = []
author = []
price = []
image = []
Links = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,21):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    title += [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
    author += [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
    price += [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
    image += [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = title
data_multipage['Author'] = author
data_multipage['Price'] = price
data_multipage['Image'] = image
data_multipage['Link'] = Links

data_multipage
# Out:
#                                                  Title  \
# 0                                                   A+
# 1                                             Lavender
# 2       Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4
# 3                               30 Doa Salafush Shalih
# 4                 Ramuan Tradisional Anti Segala Virus
# ..                                                 ...
# 215  Smp/Mts Buku Interaktif Kl.8 Matematika Smt.2 ...
# 216                  Kawanan Dinosaurus 3: Petualangan
# 217                              LC: Bakemonogatari 07
# 218                                 LC: Shiomi-chan 04
# 219                          Dragon Ball Super Vol. 13
#
#                               Author       Price  \
# 0                      Ananda Putri    Rp 84.575
# 1               Astri Salvia Aznani    Rp 80.750
# 2     Prof. Dr. Muhammad az-Zuhaili   Rp 204.000
# 3                         OMAR None    Rp 58.650
# 4                    Argo Wikanjati    Rp 51.000
# ..                               ...         ...
# 215                 Dini Fima Udari    Rp 29.750
# 216                     Lars Maehle    Rp 35.000
# 217             NISIOISIN,OH!GREAT     Rp 28.000
# 218                   KAZUROU INOUE    Rp 28.000
# 219                  Akita Toriyama    Rp 32.000
#
#                                                  Image  \
# 0    https://cdn.gramedia.com/uploads/items/A__w149...
# 1    https://cdn.gramedia.com/uploads/items/Lavende...
# 2                   /assets/default-images/product.png
# 3    https://cdn.gramedia.com/uploads/items/30_Doa_...
# 4    https://cdn.gramedia.com/uploads/items/Ramuan_...
# ..                                                 ...
# 215                 /assets/default-images/product.png
# 216                 /assets/default-images/product.png
# 217                 /assets/default-images/product.png
# 218                 /assets/default-images/product.png
# 219                 /assets/default-images/product.png
#
#                                                   Link
# 0                https://www.gramedia.com/products/a-3
# 1           https://www.gramedia.com/products/lavender
# 2    https://www.gramedia.com/products/fiqih-al-mut...
# 3    https://www.gramedia.com/products/30-doa-salaf...
# 4    https://www.gramedia.com/products/ramuan-tradi...
# ..                                                 ...
# 215  https://www.gramedia.com/products/smpmts-buku-...
# 216  https://www.gramedia.com/products/kawanan-dino...
# 217  https://www.gramedia.com/products/lc-bakemonog...
# 218  https://www.gramedia.com/products/lc-shiomi-ch...
# 219  https://www.gramedia.com/products/dragon-ball-...
#
# [220 rows x 5 columns]

# %%
from time import sleep
from random import randint
# from splinter import Browser

title = []
author = []
price = []
image = []
Links = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,21):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    sleep(randint(10,15))

    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    title += [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
    author += [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
    price += [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
    image += [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = title
data_multipage['Author'] = author
data_multipage['Price'] = price
data_multipage['Image'] = image
data_multipage['Link'] = Links

data_multipage
# Out:
#                                                  Title  \
# 0                                                   A+
# 1                                             Lavender
# 2       Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4
# 3                               30 Doa Salafush Shalih
# 4                 Ramuan Tradisional Anti Segala Virus
# ..                                                 ...
# 395                               Jodoh Sang Superstar
# 396                                      Haru Mahameru
# 397  Ekonomi, Politik Dan Peluang Bisnis Di Negara-...
# 398  Cookie Run Sweet Escape Adventure! - Hi-Tech T...
# 399                            Jurnal Mukai Usagido 02
#
#                                Author       Price  \
# 0                       Ananda Putri    Rp 84.575
# 1                Astri Salvia Aznani    Rp 80.750
# 2      Prof. Dr. Muhammad az-Zuhaili   Rp 204.000
# 3                          OMAR None    Rp 58.650
# 4                     Argo Wikanjati    Rp 51.000
# ..                                ...         ...
# 395                    Santy DIliana    Rp 75.650
# 396                                     Rp 58.650
# 397           MOHAMAD BAWAZEER, DKK.   Rp 148.750
# 398   Seoul Cultural Publisher, Inc.    Rp 68.000
# 399                      HISA TAKANO    Rp 19.600
#
#                                                  Image  \
# 0    https://cdn.gramedia.com/uploads/items/A__w149...
# 1    https://cdn.gramedia.com/uploads/items/Lavende...
# 2                   /assets/default-images/product.png
# 3    https://cdn.gramedia.com/uploads/items/30_Doa_...
# 4    https://cdn.gramedia.com/uploads/items/Ramuan_...
# ..                                                 ...
# 395                 /assets/default-images/product.png
# 396                 /assets/default-images/product.png
# 397                 /assets/default-images/product.png
# 398                 /assets/default-images/product.png
# 399                 /assets/default-images/product.png
#
#                                                   Link
# 0                https://www.gramedia.com/products/a-3
# 1           https://www.gramedia.com/products/lavender
# 2    https://www.gramedia.com/products/fiqih-al-mut...
# 3    https://www.gramedia.com/products/30-doa-salaf...
# 4    https://www.gramedia.com/products/ramuan-tradi...
# ..                                                 ...
# 395  https://www.gramedia.com/products/jodoh-sang-s...
# 396    https://www.gramedia.com/products/haru-mahameru
# 397  https://www.gramedia.com/products/ekonomi-poli...
# 398  https://www.gramedia.com/products/cookie-run-s...
# 399  https://www.gramedia.com/products/jurnal-mukai...
#
# [400 rows x 5 columns]

# %%
Title = []
Author = []
Price = []
Image = []
Links = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,21):
    
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    

    title = []

    while len(title) == 0:
        sleep(0.5)
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")

        title = [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
        author = [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
        price = [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
        image = [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

        Title += title
        Author += author
        Price += price 
        Image += image

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = Title
data_multipage['Author'] = Author
data_multipage['Price'] = Price
data_multipage['Image'] = Image
data_multipage['Link'] = Links

data_multipage
# Out:
#                                                  Title  \
# 0                       Jangan Pusingkan Omongan Orang
# 1                                   Un1Ty In Diversity
# 2                                                   A+
# 3                                             Lavender
# 4       Fiqih Al-Mu`Tamad Fiqih Hukum Keluarga Jilid 4
# ..                                                 ...
# 395                             Bicara Itu Ada Seninya
# 396                             Kecebong K(A)Esayangan
# 397                               Jodoh Sang Superstar
# 398                                      Haru Mahameru
# 399  Ekonomi, Politik Dan Peluang Bisnis Di Negara-...
#
#                               Author       Price  \
# 0                   Fitri Handayani    Rp 85.000
# 1                        Un1Ty None   Rp 208.000
# 2                      Ananda Putri    Rp 84.575
# 3               Astri Salvia Aznani    Rp 80.750
# 4     Prof. Dr. Muhammad az-Zuhaili   Rp 204.000
# ..                               ...         ...
# 395                     Oh Su Hyang    Rp 78.400
# 396      KAESANG DAN TIM SANG JAVAS    Rp 75.650
# 397                   Santy DIliana    Rp 75.650
# 398                                    Rp 58.650
# 399          MOHAMAD BAWAZEER, DKK.   Rp 148.750
#
#                                                  Image  \
# 0    https://cdn.gramedia.com/uploads/items/9786020...
# 1    https://cdn.gramedia.com/uploads/items/UNITY_H...
# 2    https://cdn.gramedia.com/uploads/items/A__w149...
# 3    https://cdn.gramedia.com/uploads/items/Lavende...
# 4                   /assets/default-images/product.png
# ..                                                 ...
# 395                 /assets/default-images/product.png
# 396                 /assets/default-images/product.png
# 397                 /assets/default-images/product.png
# 398                 /assets/default-images/product.png
# 399                 /assets/default-images/product.png
#
#                                                   Link
# 0    https://www.gramedia.com/products/jangan-pusin...
# 1    https://www.gramedia.com/products/un1ty-in-div...
# 2                https://www.gramedia.com/products/a-3
# 3           https://www.gramedia.com/products/lavender
# 4    https://www.gramedia.com/products/fiqih-al-mut...
# ..                                                 ...
# 395  https://www.gramedia.com/products/bicara-itu-a...
# 396  https://www.gramedia.com/products/kecebong-kae...
# 397  https://www.gramedia.com/products/jodoh-sang-s...
# 398    https://www.gramedia.com/products/haru-mahameru
# 399  https://www.gramedia.com/products/ekonomi-poli...
#
# [400 rows x 5 columns]

# %%
title = []
author = []
price = []
desc = []
num_pages = []
date_issue = []
publisher = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,3):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            link = "https://www.gramedia.com"+tag.find('a',{"_ngcontent-web-gramedia-c26":""})['href']
            driver.get(link)
            html_ind = driver.page_source
            soup_ind = BeautifulSoup(html_ind, "html.parser")

            title.append( soup_ind.find( 'div', {"class":"book-title"} ).get_text() )
            author.append( soup_ind.find('span',{"class":"title-author"}).get_text() )
            price.append( soup_ind.find('div', {'class':'price-product'}).get_text() )
            desc.append( soup_ind.find('pre').get_text() )
            num_pages.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[0].get_text() )
            date_issue.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[2].get_text() )
            publisher.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[1].get_text() )

        except:
            pass

pages = pd.DataFrame()
pages['Title'] = title
pages['Author'] = author
pages['Price'] = price
pages['Desc'] = desc
pages['Num Pages'] = num_pages
pages['Date Issue'] = date_issue
pages['Publisher'] = publisher

pages
# Out:
#                                                 Title  \
# 0   Buku Bisakah Aku yang Pelupa Memiliki Ingatan ...
# 1                            The Art of Self Talk-ing
# 2        Petualangan Lu si Ulat Bulu : Topi Jerami Lu
# 3    Petualangan Lu si Ulat Bulu : Apakah Lu diculik?
# 4     Petualangan Lu si Ulat Bulu : Kenari Untuk Pipu
# 5                                     KOLONI Sinawang
# 6   Plants VS Zombies - Komik Dinosaurus : Berburu...
# 7   Plants VS Zombies - Komik Dinosaurus : Pertaru...
# 8   Akasha : Re: Zero, Starting Life In Another Wo...
# 9        AKASHA : Wotakoi : Love is Hard for Otaku 04
# 10                 Haikyu!!: Fly High! Volleyball! 27
# 11                                    LC: BLOOD LAD 9
# 12                           LC: Shiomi-chan 05 (END)
# 13             YOUTH X MACHINEGUN Aoharu x Kikanju 01
# 14                  The Quintessential Quintuplets 14
# 15                             365 Aktivitas TOP PAUD
# 16                Job? Akulah Ahlinya Baking & Pastry
# 17                     Media Sosial, Suatu Alternatif
# 18        Wanita-wanita Tangguh di Sekitar Rasulullah
# 19                               Semua Bisa Investasi
# 20  Artificial Intelligence: Perspektif Manajemen ...
# 21      55+ Aktivitas Calistung Mengenal Fungsi Benda
# 22               55+ Aktivitas Calistung Anak GEMBIRA
#
#                                             Author                 Price  \
# 0                                   Cho Shin Young  Rp 100.000Rp 125.000
# 1                                 Nisrina P. Utami    Rp 56.000Rp 70.000
# 2                                        Norrattri    Rp 52.000Rp 65.000
# 3                                        Norrattri    Rp 52.000Rp 65.000
# 4                                        Norrattri    Rp 52.000Rp 65.000
# 5                         Dedy Koerniawan Soesanto    Rp 36.000Rp 45.000
# 6                                    Xiao Jiangnan   Rp 84.000Rp 105.000
# 7                                    Xiao Jiangnan   Rp 84.000Rp 105.000
# 8                               TAPPEI NAGATSUKI,     Rp 36.000Rp 45.000
# 9                                           FUJITA    Rp 32.000Rp 40.000
# 10                               Haruichi Furudate    Rp 22.400Rp 28.000
# 11                                    Yuuki KODAMA    Rp 24.000Rp 30.000
# 12                                   Inoue Kazurou    Rp 32.000Rp 40.000
# 13                                            Naoe    Rp 36.000Rp 45.000
# 14                                     Negi Haruba    Rp 40.000Rp 50.000
# 15                                 Kanaya Larasati    Rp 64.000Rp 80.000
# 16                                Kugil Publishing   Rp 80.000Rp 100.000
# 17  DR. H. DAS`AD LATIF, S. SOS, S. AG, M.SI, PH.D    Rp 48.000Rp 60.000
# 18                     Mahmud Mahdi Al Istanbuli,    Rp 92.000Rp 115.000
# 19                               Thomas Athanasius    Rp 48.000Rp 60.000
# 20                              Manerep Pasaribu,   Rp 124.000Rp 155.000
# 21                                  A. TABI`IN DKK    Rp 47.200Rp 59.000
# 22                                  A. TABI`IN DKK    Rp 47.200Rp 59.000
#
#                                                  Desc Num Pages  Date Issue  \
# 0                       Pesatnya perkembangan tekn...       284  9 Feb 2022
# 1                       Kadang, kita sibuk mendeng...       152  9 Feb 2022
# 2                       Lu dan Bibo senang sekali ...        56  9 Feb 2022
# 3                       Saat sedang bersantai bers...        56  9 Feb 2022
# 4                       Oh, tidak! Lu dan Pipu dal...        56  9 Feb 2022
# 5                       Ada satu waktu saat frekue...       152  9 Feb 2022
# 6                       Gara-gara teman-teman lain...       176  9 Feb 2022
# 7                       Gara-gara teman-teman lain...       176  9 Feb 2022
# 8                       Setelah insiden Hewan Magi...       192  9 Feb 2022
# 9                       Setelah menjalani kencan n...       136  9 Feb 2022
# 10                      Pertandingan pertama di tu...       192  9 Feb 2022
# 11                      Duel serius dari generasi ...       184  9 Feb 2022
# 12                      Yakuza nomor satu se-Jepan...       168  9 Feb 2022
# 13                      Hotaru Tachibana, murid SM...       210  9 Feb 2022
# 14                      Sebagai guru bimbel, Futar...       208  9 Feb 2022
# 15                      365 Aktivitas TOP PAUD ber...       128  9 Feb 2022
# 16                      Apakah kalian suka memakan...       176  9 Feb 2022
# 17                      Dalam buku ini, penulis me...       136  9 Feb 2022
# 18                      Perjalanan panjang sejarah...       192  9 Feb 2022
# 19                      Dalam jangka panjang, saha...       120  9 Feb 2022
# 20                      Artificial intelligence (A...       352  9 Feb 2022
# 21                      Seri 55+ Aktivitas Calistu...        80  9 Feb 2022
# 22                      Seri 55+ Aktivitas Calistu...        80  9 Feb 2022
#
#                          Publisher
# 0              Bhuana Ilmu Populer
# 1            Elex Media Komputindo
# 2                             m&c!
# 3                             m&c!
# 4                             m&c!
# 5                             m&c!
# 6                             m&c!
# 7                             m&c!
# 8                             m&c!
# 9                             m&c!
# 10                            m&c!
# 11           Elex Media Komputindo
# 12           Elex Media Komputindo
# 13           Elex Media Komputindo
# 14           Elex Media Komputindo
# 15           Elex Media Komputindo
# 16           Elex Media Komputindo
# 17           Elex Media Komputindo
# 18           Elex Media Komputindo
# 19           Elex Media Komputindo
# 20    Kepustakaan Populer Gramedia
# 21  Gramedia Widiasarana Indonesia
# 22  Gramedia Widiasarana Indonesia

# %% [markdown]
# Instagram Scrapping
#
# https://github.com/MariyaSha/WebscrapingInstagram
